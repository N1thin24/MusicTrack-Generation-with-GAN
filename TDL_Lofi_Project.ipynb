# %%
import sys
import matplotlib.pyplot as plt
import numpy as np
import pickle
import glob
import random
from __future__ import print_function, division
from music21 import converter, instrument, note, chord, stream
from keras.layers import Input, Dense, Reshape, Dropout, LSTM, Bidirectional
from keras.layers import BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from keras.utils import np_utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def get_notes():
    """ Get all the notes and chords from the midi files """
    notes = []

    for file in glob.glob("/content/drive/MyDrive/TDL Project/midi_songs/*.mid"):
        midi = converter.parse(file)

        print("Parsing %s" % file)

        notes_to_parse = None

        try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse()
        except: # file has notes in a flat structure
            notes_to_parse = midi.flat.notes

        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))

    return notes

# %%
def prepare_sequences(notes, n_vocab):
    """ Prepare the sequences used by the Neural Network """
    sequence_length = 100

    # Get all pitch names
    pitchnames = sorted(set(item for item in notes))

    # Create a dictionary to map pitches to integers
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))

    network_input = []
    network_output = []

    # create input sequences and the corresponding outputs
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        sequence_out = notes[i + sequence_length]
        network_input.append([note_to_int[char] for char in sequence_in])
        network_output.append(note_to_int[sequence_out])

    n_patterns = len(network_input)

    # Reshape the input into a format compatible with LSTM layers
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))

    # Normalize input between -1 and 1
    network_input = (network_input - float(n_vocab)/2) / (float(n_vocab)/2)
    network_output = np_utils.to_categorical(network_output)

    return (network_input, network_output)

# %%
def generate_notes(model, network_input, n_vocab):
    """ Generate notes from the neural network based on a sequence of notes """
    # pick a random sequence from the input as a starting point for the prediction
    start = numpy.random.randint(0, len(network_input)-1)

    # Get pitch names and store in a dictionary
    pitchnames = sorted(set(item for item in notes))
    int_to_note = dict((number, note) for number, note in enumerate(pitchnames))

    pattern = network_input[start]
    prediction_output = []

    # generate 500 notes
    for note_index in range(500):
        prediction_input = numpy.reshape(pattern, (1, len(pattern), 1))
        prediction_input = prediction_input / float(n_vocab)

        prediction = model.predict(prediction_input, verbose=0)

        index = numpy.argmax(prediction)
        result = int_to_note[index]
        prediction_output.append(result)

        pattern = numpy.append(pattern,index)
        #pattern.append(index)
        pattern = pattern[1:len(pattern)]

    return prediction_output

# %%
def create_midi(prediction_output, filename):
    """ convert the output from the prediction to notes and create a midi file
        from the notes """
    offset = 0
    output_notes = []

    # create note and chord objects based on the values generated by the model
    for item in prediction_output:
        pattern = item[0]
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        # pattern is a note
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)

        # increase offset each iteration so that notes do not stack
        offset += 0.5
    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp='{}.mid'.format(filename))

# %%
class GAN():
    def __init__(self, rows):
        self.seq_length = rows
        self.seq_shape = (self.seq_length, 1)
        self.latent_dim = 1000
        self.disc_loss = []
        self.gen_loss =[]

        optimizer = Adam(0.0002, 0.5)

        # Build and compile the discriminator
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

        # Build the generator
        self.generator = self.build_generator()

        # The generator takes noise as input and generates note sequences
        z = Input(shape=(self.latent_dim,))
        generated_seq = self.generator(z)

        # For the combined model we will only train the generator
        self.discriminator.trainable = True

        # The discriminator takes generated images as input and determines validity
        validity = self.discriminator(generated_seq)

        # The combined model  (stacked generator and discriminator)
        # Trains the generator to fool the discriminator
        self.combined = Model(z, validity)
        self.combined.compile(loss='binary_crossentropy', optimizer=optimizer)

    def build_discriminator(self):

        model = Sequential()
        model.add(LSTM(512, input_shape=self.seq_shape, return_sequences=True))
        model.add(Bidirectional(LSTM(512)))
        model.add(Dense(512))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(256))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(1, activation='sigmoid'))

        model.summary()

        seq = Input(shape=self.seq_shape)
        validity = model(seq)

        return Model(seq, validity)

    def build_generator(self):

        model = Sequential()
        model.add(Dense(256, input_dim=self.latent_dim))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(512))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(1024))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(np.prod(self.seq_shape), activation='tanh'))
        model.add(Reshape(self.seq_shape))
        model.summary()

        noise = Input(shape=(self.latent_dim,))
        seq = model(noise)

        return Model(noise, seq)

    def train(self, epochs, batch_size=128, sample_interval=50):

        # Load and convert the data
        notes = get_notes()
        n_vocab = len(set(notes))
        X_train, y_train = prepare_sequences(notes, n_vocab)

        # Adversarial ground truths
        real = np.ones((batch_size, 1))
        fake = np.zeros((batch_size, 1))

        # Training the model
        for epoch in range(epochs):

            # Training the discriminator
            # Select a random batch of note sequences
            idx = np.random.randint(0, X_train.shape[0], batch_size)
            real_seqs = X_train[idx]

            #noise = np.random.choice(range(484), (batch_size, self.latent_dim))
            #noise = (noise-242)/242
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))
            # Generate a batch of new note sequences
            gen_seqs = self.generator.predict(noise)

            # Train the discriminator
            d_loss_real = self.discriminator.train_on_batch(real_seqs, real)
            d_loss_fake = self.discriminator.train_on_batch(gen_seqs, fake)
            d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)


            #  Training the Generator
            noise = np.random.normal(0, 1, (batch_size, self.latent_dim))

            # Train the generator (to have the discriminator label samples as real)
            g_loss = self.combined.train_on_batch(noise, real)

            # Print the progress and save into loss lists
            if epoch % sample_interval == 0:
              print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_loss[0], 100*d_loss[1], g_loss))
              self.disc_loss.append(d_loss[0])
              self.gen_loss.append(g_loss)

        self.generate(notes,n_vocab)
        self.plot_loss()

    def generate(self, input_notes,n_vocab):
        # Get pitch names and store in a dictionary
        notes = input_notes
        pitchnames = sorted(set(item for item in notes))
        int_to_note = dict((number,note) for number,note in enumerate(pitchnames))

        # Use random noise to generate sequences
        noise = np.random.normal(0, 1, (1, self.latent_dim))
        predictions = self.generator.predict(noise)
        pred_notes = [((x+1)*(n_vocab)/2) for x in predictions[0]]
        pred_notes = [int_to_note[int(x)] for x in pred_notes]

        create_midi(pred_notes, 'gan_final')

    def plot_loss(self):
        plt.plot(self.disc_loss, c='red')
        plt.plot(self.gen_loss, c='blue')
        plt.title("GAN Loss per Epoch")
        plt.legend(['Discriminator', 'Generator'])
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.savefig('GAN_Loss_per_Epoch_final.png', transparent=True)
        plt.close()

# %%
if __name__ == '__main__':
  gan = GAN(rows=100)
  gan.train(epochs=10, batch_size=64, sample_interval=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 512)          1052672
#
#  bidirectional (Bidirectiona  (None, 1024)             4198400
#  l)
#
#  dense (Dense)               (None, 512)               524800
#
#  leaky_re_lu (LeakyReLU)     (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 5,907,457
# Trainable params: 5,907,457
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               256256
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 256)               0
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dense_4 (Dense)             (None, 512)               131584
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 512)               0
#
#  batch_normalization_1 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_5 (Dense)             (None, 1024)              525312
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 1024)              0
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_6 (Dense)             (None, 100)               102500
#
#  reshape (Reshape)           (None, 100, 1)            0
#
# =================================================================
# Total params: 1,022,820
# Trainable params: 1,019,236
# Non-trainable params: 3,584
# _________________________________________________________________
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/10.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 6 - D Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 12 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (6).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/14.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 4 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/merge_from_ofoct.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano 2 MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/16.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano Chords MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 11 - A Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 20 - A# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (3).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 1 - C Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI 2.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 2 - C# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 6 - D Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 13 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 4 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/E-Piano MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (6).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (7).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 16 - F# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 14 - F Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI 1.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 13 - E Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 17 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/2.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano Chords MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (9).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 15 - F# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 19 - A# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 20 - G Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 7 - E Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 8 - F Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 10 - F Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 2 - C# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 5 - D Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/3.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (5).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (8).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 19 - G Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 1 - C# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/18.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 12 - E Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/8.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/13.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/4.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/11.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 21 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/1.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (7).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano Chords MIDI (3).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 9 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/E-Piano MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/17.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 14 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/5.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 11 - E Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/20.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 8 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/15.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/E-Piano Chords MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 22 - B Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 15 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (3).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/12.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 16 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 9 - F Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 7 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 10 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 18 - G Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 3 - C# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 18 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (4).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (5).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (4).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 5 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/6.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (8).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 3 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/19.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 21 - A# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/9.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 22 - B Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/7.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 17 - G Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano 1 MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Lofi Piano MIDI.mid
# [[-2.16586328  0.0162573   1.15945331 ... -2.0196781  -0.92083367
#   -0.81543834]
#  [-0.12431515 -0.57378223  1.80847304 ...  0.48680914 -1.33081285
#    0.31009382]
#  [-0.48129006  0.71269013  0.55342767 ... -0.87807685  0.51120982
#   -0.49688279]
#  ...
#  [ 0.04151846  0.23813319  1.45017921 ...  2.25417716  0.26309299
#   -0.72137821]
#  [-0.35899711 -0.17138508 -0.01724949 ... -0.25881857 -0.4349629
#   -0.12638058]
#  [ 0.42706376  0.30034511 -0.3682956  ... -0.87589941 -1.68755398
#    1.31294559]]
# 0 [D loss: 0.691838, acc.: 53.12%] [G loss: 0.688549]
# [[ 0.20106016 -1.12783613  1.27406057 ...  1.7263274   0.11124286
#    1.30333317]
#  [ 0.63783548 -0.0489139   0.29686617 ...  0.09446041  0.11897266
#   -0.44214049]
#  [ 0.11485292 -0.29302343 -0.32056789 ...  1.04389216 -0.98716778
#    1.516355  ]
#  ...
#  [-1.05801589  0.55972134  1.26986374 ... -0.5093565   1.03998331
#    0.56898202]
#  [ 1.05527907 -1.94551683  1.1841548  ... -1.41811126  0.01676767
#   -0.06467506]
#  [-0.96677881 -1.81308573  0.97086368 ...  1.05933814  0.04700321
#   -0.86993301]]
# 1 [D loss: 0.667399, acc.: 67.97%] [G loss: 0.676410]
# [[-1.13492655  0.10927679  0.10910476 ... -1.93346699  0.10260871
#   -0.03346264]
#  [ 0.4339607  -1.54864853  0.82145025 ...  1.05975757  0.90488179
#   -0.02769038]
#  [ 1.76917047  0.66960764  0.1378142  ... -0.70851267 -0.63825307
#    1.07781873]
#  ...
#  [ 2.35610196  0.09963951  0.11150996 ...  0.81924575  0.25877878
#    0.70800189]
#  [-0.94285492 -0.43934845 -1.9886202  ...  0.32004791 -0.14187921
#    1.07906233]
#  [-2.18788974 -0.62899267 -0.30146281 ... -0.70057219 -0.98939263
#    0.81188154]]
# 2 [D loss: 0.623448, acc.: 64.84%] [G loss: 0.640719]
# [[-0.44732314 -0.09626518  0.38674204 ... -1.27820226  1.04138691
#    0.80298267]
#  [-0.25646341  0.80298285 -3.37465348 ...  0.03193987  1.01944573
#   -1.75994899]
#  [ 1.22894223  1.03055919 -0.68800694 ... -0.36968832 -0.62692216
#    1.21831406]
#  ...
#  [ 0.70216637 -1.16657759 -0.83889996 ...  0.27732018  0.38511728
#   -0.56561322]
#  [ 0.73274374  0.99156268  1.67798715 ...  0.64924924  0.41092063
#   -0.98369124]
#  [ 0.82997551  0.44728952 -2.22860149 ...  0.98691931  0.29103936
#    0.13024727]]
# 3 [D loss: 0.555823, acc.: 60.94%] [G loss: 0.580612]
# [[ 1.52741929  0.15338608  1.83605371 ... -0.32599515 -0.40332595
#    1.19479415]
#  [ 0.11689455 -0.86887807  0.5403881  ... -2.25375343  0.12564136
#   -1.33985538]
#  [-1.36865709  0.83242079 -3.05545863 ...  0.62271385 -1.31736706
#   -2.3520829 ]
#  ...
#  [-0.36174271 -1.06556344  2.29125336 ... -1.10718578  0.39524103
#    0.20139643]
#  [ 0.14837015 -0.04996277 -0.66910905 ...  0.07820854  2.11407539
#   -0.09497102]
#  [-0.56717414  0.90616847  0.2582582  ... -1.04887895 -1.46698435
#   -0.87089466]]
# 4 [D loss: 0.582859, acc.: 67.97%] [G loss: 0.583055]
# [[ 0.10045568 -0.23666136  0.52016323 ... -0.00660612  0.09348952
#    0.79389943]
#  [ 0.82290178  0.69877856  1.25850789 ...  1.5997239  -0.64570971
#   -1.03159276]
#  [-2.08056497  1.8690472   0.08768257 ...  0.72932091  0.82556897
#    0.58383589]
#  ...
#  [ 0.89239545  0.1386259  -0.79267574 ... -0.10002917 -0.32806062
#    0.0154907 ]
#  [ 0.30048121 -1.53501362  2.17849329 ...  0.68418396 -0.60292708
#    1.34867815]
#  [-1.21050102  0.15055057  1.83494842 ...  0.55699141  0.16531115
#   -0.42395201]]
# 5 [D loss: 0.494338, acc.: 70.31%] [G loss: 0.571018]
# [[-1.70576916 -0.71344433  2.44144911 ... -0.71465382 -0.03589764
#    0.74828718]
#  [-1.28300414  0.71317797  0.755218   ... -0.82374964 -1.34252238
#   -0.67322808]
#  [ 0.68934314  0.24426645  1.03624896 ...  0.81962711 -0.5017702
#   -0.17260389]
#  ...
#  [ 0.1663032  -1.94199408 -1.44935114 ... -1.2756063   0.99999839
#    0.71126966]
#  [-1.46020393  0.1823054   0.57143852 ...  1.37881514 -1.87703699
#   -0.31049156]
#  [-1.00482985 -0.98793895 -0.10762605 ... -0.84751562 -1.35840797
#   -0.4236299 ]]
# 6 [D loss: 0.606469, acc.: 72.66%] [G loss: 0.598920]
# [[ 0.96765319  0.06937842  1.09852791 ...  0.09108646 -0.08124441
#    0.17952155]
#  [ 1.48734717  1.29975226  0.90154173 ... -0.89981315 -0.41934159
#   -1.36346905]
#  [-1.86580692  0.01155013  1.06932499 ... -0.24404303  2.64035764
#   -0.20766265]
#  ...
#  [-1.01205928 -0.40749016 -0.28073776 ... -1.35662568  0.28246864
#    0.48206065]
#  [-1.25309419  0.49953937 -0.97072211 ... -1.21418528  0.25276361
#   -1.04623489]
#  [ 1.62330514 -0.76793297 -0.72081926 ... -0.27003556 -0.4775953
#   -0.98353134]]
# 7 [D loss: 0.522829, acc.: 72.66%] [G loss: 0.591798]
# [[-1.08818938 -0.10268158 -0.1917954  ... -1.22362424 -0.69157793
#    0.59461   ]
#  [ 0.55614582 -0.23674161  0.4439967  ... -0.17216722 -0.65420296
#   -1.49761199]
#  [ 2.00418024  0.68733519 -0.54023201 ... -0.79800777 -0.44772211
#   -0.82625459]
#  ...
#  [ 0.08395721 -0.03476792  0.82652791 ... -0.27950164 -1.94249912
#    0.19917953]
#  [ 0.12489634 -0.14884536 -0.49088862 ...  0.39963953 -0.34690179
#   -0.47645786]
#  [-0.34164839 -3.03242358 -0.24292144 ... -0.34259225 -0.09453533
#    0.77130528]]
# 8 [D loss: 0.566329, acc.: 71.88%] [G loss: 0.580079]
# [[-0.22001339 -0.14636877 -0.5794523  ...  1.21024767  0.95643307
#   -0.19337706]
#  [ 0.16439022 -1.13294241 -0.06417139 ... -0.44040993 -0.45491975
#    1.82859022]
#  [ 0.39474712  0.15663885 -1.11290835 ...  0.40109884 -1.37640601
#    0.90749788]
#  ...
#  [-0.13274371 -0.26135274  0.52375942 ... -0.24388632  1.28344217
#    0.29526401]
#  [-0.02533066  0.16518468 -0.86221651 ... -0.91681512 -1.10836837
#    1.07545175]
#  [ 0.14415196 -0.48761574  0.46161028 ... -0.16201391 -0.30839912
#    1.26270584]]
# 9 [D loss: 0.547224, acc.: 71.88%] [G loss: 0.573654]

# %%
tester=get_notes()
print(tester)
# Out:
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/10.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 6 - D Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 12 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (6).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/14.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 4 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/merge_from_ofoct.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano 2 MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/16.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano Chords MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 11 - A Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 20 - A# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (3).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 1 - C Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI 2.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 2 - C# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 6 - D Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 13 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 4 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/E-Piano MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (6).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (7).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 16 - F# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 14 - F Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI 1.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 13 - E Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 17 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/2.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano Chords MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (9).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 15 - F# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 19 - A# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 20 - G Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 7 - E Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 8 - F Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 10 - F Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 2 - C# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 5 - D Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/3.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (5).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (8).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 19 - G Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 1 - C# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/18.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 12 - E Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/8.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/13.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/4.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/11.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 21 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/1.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (7).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano Chords MIDI (3).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 9 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/E-Piano MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/17.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 14 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/5.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 11 - E Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/20.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 8 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/15.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/E-Piano Chords MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 22 - B Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 15 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (3).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/12.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 16 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 9 - F Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 7 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 10 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 18 - G Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 3 - C# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 18 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (4).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (5).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (4).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 5 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/6.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (8).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 3 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/19.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 21 - A# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/9.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 22 - B Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/7.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 17 - G Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano 1 MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Lofi Piano MIDI.mid
# ['9.0', '11.4', 'D6', 'E4', 'G4', 'E5', '4.7.11', '2.6', 'F#4', 'E5', 'B4', 'G5', '9.0', '11.4', 'D6', 'E4', 'G4', 'E5', '4.7.11', '2.6', 'F#4', 'E5', 'G5', 'E-3', 'E-2', 'G3', '10.2', 'C2', '7.10.0.3', 'B-1', 'B-2', 'D3', 'A3', 'F3', 'E-2', '3.7', 'D4', 'E-5', 'G5', '10.2', 'C2', '0.3', '0.3', '7', '10', '10', 'B-4', '2', '9', 'F5', 'D3', '5.9.0', 'E4', 'A4', 'G4', '2.5.9', 'E4', 'D4', '9.0', '4.7', 'C4', '4.7.9.0', '7.9', '10.2.5', '5.9.0', 'C5', 'D5', '4.5.9.0', '4.5.9.0', 'C5', 'E5', 'D5', 'B4', 'C5', 'B4', 'G4', '9.0.2.5', 'G4', '9.0.2.5', 'G4', 'E4', 'D4', 'G4', 'A4', 'C5', '4.5.9.0', '4.5.9.0', 'C5', 'E5', 'D5', 'B4', 'C5', 'G5', 'E5', '9.0.2.5', 'E5', '9.0.2.5', 'E5', 'D5', 'D4', '2.5.9', 'G4', 'A4', 'C5', 'F3', '5.9', 'E5', 'C5', 'C5', 'A4', 'G4', 'B-3', 'B-2', 'D4', 'A4', 'F4', 'C#3', 'C#4', '5.8.0', 'G#4', 'C#4', '0.4', '7.9', '2.5', '7.9', '4.9', '11.2', '7.11', '2.4.9', '0.3.7', 'G4', 'E-5', 'D5', 'G4', '5.8.0', '10.3', 'C4', '0.3.5.8', 'F5', 'G#4', 'E-5', 'F4', '7.10.2', '0.5', 'G#4', '0.3.7', 'G4', 'E-5', 'D5', 'G4', '5.8.0', 'G#5', '10.3', 'G5', 'C4', '0.3.5.8', 'F5', 'G#4', 'E-5', 'F4', '7.10.2', 'G#5', '0.5', 'G5', 'G#4', 'E-5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '5.9.10', 'D4', '4.5.9.0', 'E-2', 'E-3', '7.10.2', 'C#6', 'E-6', 'F6', 'B-6', 'G#6', 'F6', 'E-6', 'C#6', 'B-5', 'C#6', 'C#6', 'E-6', 'F6', 'B-6', 'G#6', 'F6', 'E-6', 'C#6', 'B-5', 'C#6', '4.5.7.9.0', '9.0.2.5', '11.2.4.7', '4.5.9.0', '4.5.7.9.0', '9.0.2.5', '11.2.4.7', '4.5.9.0', 'E-3', 'F#3', 'B-3', 'C#4', 'F3', 'G#3', 'C4', 'E-4', 'B-4', 'B-3', 'C#5', 'C#4', 'F5', 'F4', 'G#5', 'G#4', 'F4', 'F3', 'G#3', '8.0', 'C4', 'E-5', 'E-4', 'F#1', '9.11.4', '1', '11', '9.11.1.4', 'C#4', '9.11.1.4', '9', '8.11.1.4', '11.1', '1', '7.10.0.3', 'C#4', 'B1', '2.6.9', '4', 'C#4', '11', 'C#4', 'D2', '6.9.1', 'C#4', 'C#4', '9', 'F#1', '9.11.4', '1', '11', '9.11.1.4', 'C#4', '9.11.1.4', '9', '8.11.1.4', '11.1', '1', '7.10.0.3', 'C#4', 'B1', '2.6.9', '4', 'C#4', '6', 'C#4', 'D2', '6.9.1', '1.4', '9.1', '5.8.10.1', 'F#3', 'B3', '3.4.8', 'F#4', 'B3', 'F3', '5.8.10.1', 'F#3', 'B3', '3.4.8', 'F#4', 'B3', 'F3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'C3', 'F3', 'A3', 'E4', 'G6', 'F6', 'E6', 'A5', 'G5', 'D6', 'E5', 'C3', 'E6', 'G3', 'B3', 'E4', 'G5', 'G3', 'C5', 'D5', 'C3', 'F3', 'A3', 'E4', 'G6', 'F6', 'E6', 'A5', 'G5', 'D6', 'E5', 'C3', 'E6', 'G3', 'B3', 'E4', 'G5', 'G3', 'C5', 'D5', '2.5.7', 'B-3', '2.5.7.10', '2.5.7', 'B-3', '2.5.7.10', '4.5.9.0', '4.5.9.0', '5.9.0', 'E4', '4.5.9.0', '1.4 ...

# %%
tester=get_notes()
print(tester)
# Out:
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/10.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 6 - D Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 12 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (6).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/14.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 4 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/merge_from_ofoct.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano 2 MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/16.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano Chords MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 11 - A Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 20 - A# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (3).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 1 - C Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI 2.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 2 - C# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 6 - D Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 13 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 4 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/E-Piano MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (6).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (7).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 16 - F# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 14 - F Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI 1.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 13 - E Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 17 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/2.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano Chords MIDI (2).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (9).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 15 - F# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 19 - A# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 20 - G Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 7 - E Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 8 - F Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 10 - F Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 2 - C# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 5 - D Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/3.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (5).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (8).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 19 - G Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 1 - C# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/18.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 12 - E Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/8.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/13.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/4.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/11.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 21 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/1.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (7).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano Chords MIDI (3).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 9 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/E-Piano MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/17.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 14 - A Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/5.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 11 - E Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/20.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 8 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/15.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/E-Piano Chords MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 22 - B Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 15 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (3).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/12.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 16 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 9 - F Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 7 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 10 - D# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 18 - G Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 3 - C# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 18 - A# Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (4).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano MIDI (5).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (4).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 5 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/6.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Rhodes MIDI (8).mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 3 - D Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/19.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Eternity MIDI 21 - A# Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/9.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 22 - B Min.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/7.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Cymatics - Lofi MIDI 17 - G Maj.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Piano 1 MIDI.mid
# Parsing /content/drive/MyDrive/TDL Project/midi_songs/Lofi Piano MIDI.mid
# ['9.0', '11.4', 'D6', 'E4', 'G4', 'E5', '4.7.11', '2.6', 'F#4', 'E5', 'B4', 'G5', '9.0', '11.4', 'D6', 'E4', 'G4', 'E5', '4.7.11', '2.6', 'F#4', 'E5', 'G5', 'E-3', 'E-2', 'G3', '10.2', 'C2', '7.10.0.3', 'B-1', 'B-2', 'D3', 'A3', 'F3', 'E-2', '3.7', 'D4', 'E-5', 'G5', '10.2', 'C2', '0.3', '0.3', '7', '10', '10', 'B-4', '2', '9', 'F5', 'D3', '5.9.0', 'E4', 'A4', 'G4', '2.5.9', 'E4', 'D4', '9.0', '4.7', 'C4', '4.7.9.0', '7.9', '10.2.5', '5.9.0', 'C5', 'D5', '4.5.9.0', '4.5.9.0', 'C5', 'E5', 'D5', 'B4', 'C5', 'B4', 'G4', '9.0.2.5', 'G4', '9.0.2.5', 'G4', 'E4', 'D4', 'G4', 'A4', 'C5', '4.5.9.0', '4.5.9.0', 'C5', 'E5', 'D5', 'B4', 'C5', 'G5', 'E5', '9.0.2.5', 'E5', '9.0.2.5', 'E5', 'D5', 'D4', '2.5.9', 'G4', 'A4', 'C5', 'F3', '5.9', 'E5', 'C5', 'C5', 'A4', 'G4', 'B-3', 'B-2', 'D4', 'A4', 'F4', 'C#3', 'C#4', '5.8.0', 'G#4', 'C#4', '0.4', '7.9', '2.5', '7.9', '4.9', '11.2', '7.11', '2.4.9', '0.3.7', 'G4', 'E-5', 'D5', 'G4', '5.8.0', '10.3', 'C4', '0.3.5.8', 'F5', 'G#4', 'E-5', 'F4', '7.10.2', '0.5', 'G#4', '0.3.7', 'G4', 'E-5', 'D5', 'G4', '5.8.0', 'G#5', '10.3', 'G5', 'C4', '0.3.5.8', 'F5', 'G#4', 'E-5', 'F4', '7.10.2', 'G#5', '0.5', 'G5', 'G#4', 'E-5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '1.5', '10.1', 'C#3', 'G#5', 'F5', 'E-3', 'E-5', 'F5', 'E-5', 'C#5', 'E-3', 'C5', 'C5', 'G#3', 'G#4', 'B-4', 'C5', 'C#5', 'G#3', 'E-5', 'F5', 'B-2', 'B-4', 'C5', 'C#5', 'B-2', 'E-5', 'F5', 'G#5', '5.9.10', 'D4', '4.5.9.0', 'E-2', 'E-3', '7.10.2', 'C#6', 'E-6', 'F6', 'B-6', 'G#6', 'F6', 'E-6', 'C#6', 'B-5', 'C#6', 'C#6', 'E-6', 'F6', 'B-6', 'G#6', 'F6', 'E-6', 'C#6', 'B-5', 'C#6', '4.5.7.9.0', '9.0.2.5', '11.2.4.7', '4.5.9.0', '4.5.7.9.0', '9.0.2.5', '11.2.4.7', '4.5.9.0', 'E-3', 'F#3', 'B-3', 'C#4', 'F3', 'G#3', 'C4', 'E-4', 'B-4', 'B-3', 'C#5', 'C#4', 'F5', 'F4', 'G#5', 'G#4', 'F4', 'F3', 'G#3', '8.0', 'C4', 'E-5', 'E-4', 'F#1', '9.11.4', '1', '11', '9.11.1.4', 'C#4', '9.11.1.4', '9', '8.11.1.4', '11.1', '1', '7.10.0.3', 'C#4', 'B1', '2.6.9', '4', 'C#4', '11', 'C#4', 'D2', '6.9.1', 'C#4', 'C#4', '9', 'F#1', '9.11.4', '1', '11', '9.11.1.4', 'C#4', '9.11.1.4', '9', '8.11.1.4', '11.1', '1', '7.10.0.3', 'C#4', 'B1', '2.6.9', '4', 'C#4', '6', 'C#4', 'D2', '6.9.1', '1.4', '9.1', '5.8.10.1', 'F#3', 'B3', '3.4.8', 'F#4', 'B3', 'F3', '5.8.10.1', 'F#3', 'B3', '3.4.8', 'F#4', 'B3', 'F3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'E-4', 'E3', 'G#4', 'E3', 'B4', 'E3', 'C3', 'F3', 'A3', 'E4', 'G6', 'F6', 'E6', 'A5', 'G5', 'D6', 'E5', 'C3', 'E6', 'G3', 'B3', 'E4', 'G5', 'G3', 'C5', 'D5', 'C3', 'F3', 'A3', 'E4', 'G6', 'F6', 'E6', 'A5', 'G5', 'D6', 'E5', 'C3', 'E6', 'G3', 'B3', 'E4', 'G5', 'G3', 'C5', 'D5', '2.5.7', 'B-3', '2.5.7.10', '2.5.7', 'B-3', '2.5.7.10', '4.5.9.0', '4.5.9.0', '5.9.0', 'E4', '4.5.9.0', '1.4 ...
